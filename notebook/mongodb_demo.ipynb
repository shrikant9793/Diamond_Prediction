# %%
print("Ok")
# Out:
# Ok

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"gemstone.csv")
df.head(5)
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df.columns
# Out:
# Index(['id', 'carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y',
#        'z', 'price'],
#       dtype='object')

# %%
data = df.to_dict(orient='records')
data
# Out:
# [{'id': 0,
#   'carat': 1.52,
#   'cut': 'Premium',
#   'color': 'F',
#   'clarity': 'VS2',
#   'depth': 62.2,
#   'table': 58.0,
#   'x': 7.27,
#   'y': 7.33,
#   'z': 4.55,
#   'price': 13619},
#  {'id': 1,
#   'carat': 2.03,
#   'cut': 'Very Good',
#   'color': 'J',
#   'clarity': 'SI2',
#   'depth': 62.0,
#   'table': 58.0,
#   'x': 8.06,
#   'y': 8.12,
#   'z': 5.05,
#   'price': 13387},
#  {'id': 2,
#   'carat': 0.7,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'VS1',
#   'depth': 61.2,
#   'table': 57.0,
#   'x': 5.69,
#   'y': 5.73,
#   'z': 3.5,
#   'price': 2772},
#  {'id': 3,
#   'carat': 0.32,
#   'cut': 'Ideal',
#   'color': 'G',
#   'clarity': 'VS1',
#   'depth': 61.6,
#   'table': 56.0,
#   'x': 4.38,
#   'y': 4.41,
#   'z': 2.71,
#   'price': 666},
#  {'id': 4,
#   'carat': 1.7,
#   'cut': 'Premium',
#   'color': 'G',
#   'clarity': 'VS2',
#   'depth': 62.6,
#   'table': 59.0,
#   'x': 7.65,
#   'y': 7.61,
#   'z': 4.77,
#   'price': 14453},
#  {'id': 5,
# ...

# %%
import pymongo

# %%
DB_NAME = "DIAMOND_PRED_DB"
COLLECTION_NAME = "Gemstone_Data"
CONNECTION_URL = "mongodb+srv://shrinaths2:shrinaths2@cluster0.cxkiakv.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base =  client[DB_NAME]
collection = data_base[COLLECTION_NAME]
record = collection.insert_many(data)

# %%
df.shape
# Out:
# (193573, 11)

# %%
#downloading dataset from DB and storing it in df
df = pd.DataFrame(list(collection.find()))
df.head(5)
# Out:
#                         _id  id  carat        cut color clarity  depth  table  \
# 0  66183046b32357de9da9ea52   0   1.52    Premium     F     VS2   62.2   58.0
# 1  66183046b32357de9da9ea53   1   2.03  Very Good     J     SI2   62.0   58.0
# 2  66183046b32357de9da9ea54   2   0.70      Ideal     G     VS1   61.2   57.0
# 3  66183046b32357de9da9ea55   3   0.32      Ideal     G     VS1   61.6   56.0
# 4  66183046b32357de9da9ea56   4   1.70    Premium     G     VS2   62.6   59.0
#
#       x     y     z  price
# 0  7.27  7.33  4.55  13619
# 1  8.06  8.12  5.05  13387
# 2  5.69  5.73  3.50   2772
# 3  4.38  4.41  2.71    666
# 4  7.65  7.61  4.77  14453

# %%
#dropping "_id" column from dataframe
if "_id" in df.columns.to_list():
    df = df.drop(columns = ["_id"], axis = 1)

# %%
df.head(2)
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
